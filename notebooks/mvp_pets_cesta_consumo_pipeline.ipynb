-- %% [markdown]
-- # MVP – Pets na Cesta de Consumo
-- ## Pipeline completo (Bronze → Silver → Gold → Análise)
--
-- Este notebook reúne **todas as etapas do MVP** em um único fluxo, por limitação de criação de múltiplos notebooks na Databricks Community Edition.
--
-- Aqui estão consolidadas as três partes originalmente planejadas:
--
-- 1. **Busca e Coleta de Dados (Bronze / Silver)**
--    - Leitura do workbook do ONS (Family spending – FYE 2024, tabela A6);
--    - Criação da tabela bruta `family_spending_a6`;
--    - Limpeza e padronização em `family_spending_a6_clean`;
--    - Transformação do formato *wide* (decis em colunas) para *long* (decis em linhas) na view `vw_despesa_long`;
--    - Cálculo do gasto total por decil e da participação da categoria no orçamento em `vw_despesa_com_total`.
--
-- 2. **Modelagem e Carga da Camada Gold (Esquema Estrela)**
--    - Criação das dimensões: `dim_renda`, `dim_categoria_consumo`, `dim_tempo`, `dim_geografia`;
--    - Criação da tabela fato `fato_despesa_familiar`, com gasto médio semanal, gasto total do decil e participação da categoria no orçamento.
--
-- 3. **Análise de Teoria do Consumidor (Gastos com Pets)**
--    - Análise de qualidade de dados (valores mínimos, máximos e nulos);
--    - Cálculo da participação dos gastos com **pets** no orçamento por decil de renda;
--    - Comparação entre **Pets** e **Alimentação** (Lei de Engel);
--    - Geração de tabelas e gráficos usados na documentação do MVP.
--
-- > **Observação:** embora o plano original previsse três notebooks (`01_busca_coleta`, `02_modelagem_carga` e `03_analise_consumidor_pets`), todas as etapas foram integradas neste único notebook devido à limitação da conta gratuita do Databricks. A organização em seções internas mantém a separação lógica entre as fases do trabalho.
--
-- ---

-- %% [markdown]
-- ## 1. Configuração inicial (catálogo / schema)
--
-- Nesta seção configuramos o catálogo e o schema padrão onde as tabelas e views do MVP serão criadas.

-- %%
USE CATALOG workspace;
USE SCHEMA default;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## 2. Camada Bronze – Tabela original `family_spending_a6`
--
-- A tabela `family_spending_a6` foi criada a partir do upload do arquivo do ONS (tabela A6 do workbook 1 – FYE 2024).
-- Aqui apenas inspecionamos alguns registros para confirmar a estrutura.

-- %%
SELECT *
FROM family_spending_a6
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>code</th><th>description</th><th>d1_lowest</th><th>d2_second</th><th>d3_third</th><th>d4_fourth</th><th>d5_fifth</th><th>d6_sixth</th><th>d7_seventh</th><th>d8_eighth</th><th>d9_ninth</th><th>d10_highest</th><th>all_households</th></tr></thead><tbody><tr><td>1</td><td>Food & non-alcoholic drinks</td><td>38.1</td><td>48.3</td><td>57.0</td><td>62.5</td><td>68.6</td><td>71.3</td><td>76.7</td><td>88.7</td><td>93.2</td><td>100.9</td><td>70.5</td></tr><tr><td>1.1</td><td>Food</td><td>35.2</td><td>44.2</td><td>52.4</td><td>56.9</td><td>62.4</td><td>65.2</td><td>69.9</td><td>80.6</td><td>84.3</td><td>91.9</td><td>64.3</td></tr><tr><td>1.1.1</td><td>Bread, rice and cereals</td><td>3.3</td><td>4.0</td><td>5.2</td><td>5.2</td><td>5.9</td><td>6.6</td><td>6.6</td><td>8.2</td><td>8.2</td><td>8.6</td><td>6.2</td></tr><tr><td>1.1.2</td><td>Pasta products</td><td>0.3</td><td>0.3</td><td>0.5</td><td>0.4</td><td>0.6</td><td>0.6</td><td>0.7</td><td>0.7</td><td>0.7</td><td>0.8</td><td>0.6</td></tr><tr><td>1.1.3</td><td>Buns, cakes, biscuits etc.</td><td>2.6</td><td>3.6</td><td>4.1</td><td>4.2</td><td>4.8</td><td>4.7</td><td>5.4</td><td>6.3</td><td>6.4</td><td>6.4</td><td>4.9</td></tr><tr><td>1.1.4</td><td>Pastry (savoury)</td><td>0.6</td><td>0.5</td><td>0.7</td><td>1.0</td><td>1.1</td><td>1.2</td><td>1.2</td><td>1.5</td><td>2.0</td><td>1.3</td><td>1.1</td></tr><tr><td>1.1.5</td><td>Beef (fresh, chilled or frozen)</td><td>0.8</td><td>1.2</td><td>1.7</td><td>2.0</td><td>2.1</td><td>2.0</td><td>2.4</td><td>2.2</td><td>2.1</td><td>3.5</td><td>2.0</td></tr><tr><td>1.1.6</td><td>Pork (fresh, chilled or frozen)</td><td>0.3</td><td>0.4</td><td>0.6</td><td>0.5</td><td>0.6</td><td>0.6</td><td>0.6</td><td>0.7</td><td>0.8</td><td>0.7</td><td>0.6</td></tr><tr><td>1.1.7</td><td>Lamb (fresh, chilled or frozen)</td><td>0.3</td><td>0.4</td><td>0.6</td><td>0.7</td><td>0.4</td><td>0.6</td><td>0.6</td><td>0.6</td><td>0.4</td><td>0.9</td><td>0.5</td></tr><tr><td>1.1.8</td><td>Poultry (fresh, chilled or frozen)</td><td>1.0</td><td>1.2</td><td>2.0</td><td>1.8</td><td>2.7</td><td>2.6</td><td>2.7</td><td>3.4</td><td>3.6</td><td>3.7</td><td>2.5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 3. Camada Silver – Limpeza e seleção de colunas (`family_spending_a6_clean`)
--
-- Nesta etapa criamos a tabela `family_spending_a6_clean`, que:
-- - seleciona apenas as colunas relevantes da tabela A6;
-- - converte os valores de despesa por decil e o total para tipo numérico (`DOUBLE`).

-- %%
CREATE OR REPLACE TABLE family_spending_a6_clean AS
SELECT
  code,
  description,
  `d1_lowest`      AS d1_lowest,
  `d2_second`      AS d2_second,
  `d3_third`       AS d3_third,
  `d4_fourth`      AS d4_fourth,
  `d5_fifth`       AS d5_fifth,
  `d6_sixth`       AS d6_sixth,
  `d7_seventh`     AS d7_seventh,
  `d8_eighth`      AS d8_eighth,
  `d9_ninth`       AS d9_ninth,
  `d10_highest`    AS d10_highest,
  `all_households` AS all_households
FROM family_spending_a6;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM family_spending_a6_clean
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>code</th><th>description</th><th>d1_lowest</th><th>d2_second</th><th>d3_third</th><th>d4_fourth</th><th>d5_fifth</th><th>d6_sixth</th><th>d7_seventh</th><th>d8_eighth</th><th>d9_ninth</th><th>d10_highest</th><th>all_households</th></tr></thead><tbody><tr><td>1</td><td>Food & non-alcoholic drinks</td><td>38.1</td><td>48.3</td><td>57.0</td><td>62.5</td><td>68.6</td><td>71.3</td><td>76.7</td><td>88.7</td><td>93.2</td><td>100.9</td><td>70.5</td></tr><tr><td>1.1</td><td>Food</td><td>35.2</td><td>44.2</td><td>52.4</td><td>56.9</td><td>62.4</td><td>65.2</td><td>69.9</td><td>80.6</td><td>84.3</td><td>91.9</td><td>64.3</td></tr><tr><td>1.1.1</td><td>Bread, rice and cereals</td><td>3.3</td><td>4.0</td><td>5.2</td><td>5.2</td><td>5.9</td><td>6.6</td><td>6.6</td><td>8.2</td><td>8.2</td><td>8.6</td><td>6.2</td></tr><tr><td>1.1.2</td><td>Pasta products</td><td>0.3</td><td>0.3</td><td>0.5</td><td>0.4</td><td>0.6</td><td>0.6</td><td>0.7</td><td>0.7</td><td>0.7</td><td>0.8</td><td>0.6</td></tr><tr><td>1.1.3</td><td>Buns, cakes, biscuits etc.</td><td>2.6</td><td>3.6</td><td>4.1</td><td>4.2</td><td>4.8</td><td>4.7</td><td>5.4</td><td>6.3</td><td>6.4</td><td>6.4</td><td>4.9</td></tr><tr><td>1.1.4</td><td>Pastry (savoury)</td><td>0.6</td><td>0.5</td><td>0.7</td><td>1.0</td><td>1.1</td><td>1.2</td><td>1.2</td><td>1.5</td><td>2.0</td><td>1.3</td><td>1.1</td></tr><tr><td>1.1.5</td><td>Beef (fresh, chilled or frozen)</td><td>0.8</td><td>1.2</td><td>1.7</td><td>2.0</td><td>2.1</td><td>2.0</td><td>2.4</td><td>2.2</td><td>2.1</td><td>3.5</td><td>2.0</td></tr><tr><td>1.1.6</td><td>Pork (fresh, chilled or frozen)</td><td>0.3</td><td>0.4</td><td>0.6</td><td>0.5</td><td>0.6</td><td>0.6</td><td>0.6</td><td>0.7</td><td>0.8</td><td>0.7</td><td>0.6</td></tr><tr><td>1.1.7</td><td>Lamb (fresh, chilled or frozen)</td><td>0.3</td><td>0.4</td><td>0.6</td><td>0.7</td><td>0.4</td><td>0.6</td><td>0.6</td><td>0.6</td><td>0.4</td><td>0.9</td><td>0.5</td></tr><tr><td>1.1.8</td><td>Poultry (fresh, chilled or frozen)</td><td>1.0</td><td>1.2</td><td>2.0</td><td>1.8</td><td>2.7</td><td>2.6</td><td>2.7</td><td>3.4</td><td>3.6</td><td>3.7</td><td>2.5</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 4. Camada Silver – Transformação wide → long (`vw_despesa_long`)
--
-- A tabela A6 original apresenta os decis de renda em colunas (`d1_lowest` … `d10_highest`).
-- Aqui criamos a view `vw_despesa_long`, que coloca os dados em formato analítico *long*:
--
-- - uma linha por combinação **[categoria × decil de renda]**;
-- - coluna `decil_renda` (1 a 10);
-- - coluna `gasto_medio_semanal` com o valor correspondente ao decil.

-- %%
CREATE OR REPLACE VIEW vw_despesa_long AS
SELECT
  2024 AS ano,              -- tudo é FYE 2024
  code,
  description,
  decil_renda,
  gasto_medio_semanal
FROM family_spending_a6_clean
LATERAL VIEW STACK (
  10,
  1, d1_lowest,
  2, d2_second,
  3, d3_third,
  4, d4_fourth,
  5, d5_fifth,
  6, d6_sixth,
  7, d7_seventh,
  8, d8_eighth,
  9, d9_ninth,
  10, d10_highest
) AS decil_renda, gasto_medio_semanal;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM vw_despesa_long
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ano</th><th>code</th><th>description</th><th>decil_renda</th><th>gasto_medio_semanal</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>Food & non-alcoholic drinks</td><td>1</td><td>38.1</td></tr><tr><td>2024</td><td>1.1</td><td>Food</td><td>1</td><td>35.2</td></tr><tr><td>2024</td><td>1.1.1</td><td>Bread, rice and cereals</td><td>1</td><td>3.3</td></tr><tr><td>2024</td><td>1.1.2</td><td>Pasta products</td><td>1</td><td>0.3</td></tr><tr><td>2024</td><td>1.1.3</td><td>Buns, cakes, biscuits etc.</td><td>1</td><td>2.6</td></tr><tr><td>2024</td><td>1.1.4</td><td>Pastry (savoury)</td><td>1</td><td>0.6</td></tr><tr><td>2024</td><td>1.1.5</td><td>Beef (fresh, chilled or frozen)</td><td>1</td><td>0.8</td></tr><tr><td>2024</td><td>1.1.6</td><td>Pork (fresh, chilled or frozen)</td><td>1</td><td>0.3</td></tr><tr><td>2024</td><td>1.1.7</td><td>Lamb (fresh, chilled or frozen)</td><td>1</td><td>0.3</td></tr><tr><td>2024</td><td>1.1.8</td><td>Poultry (fresh, chilled or frozen)</td><td>1</td><td>1.0</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 5. Camada Silver – Cálculo do gasto total e participação no orçamento (`vw_despesa_com_total`)
--
-- A partir de `vw_despesa_long`, criamos a view `vw_despesa_com_total`, que adiciona:
--
-- - `gasto_medio_total_semanal` (coluna `all_households`);
-- - `participacao_orcamento` = gasto da categoria / gasto total do decil.

-- %%
CREATE OR REPLACE VIEW vw_despesa_com_total AS
WITH base AS (
  SELECT *
  FROM vw_despesa_long
),
totais AS (
  SELECT
    ano,
    decil_renda,
    SUM(gasto_medio_semanal) AS gasto_medio_total_semanal
  FROM base
  GROUP BY ano, decil_renda
)
SELECT
  b.ano,
  b.code,
  b.description,
  b.decil_renda,
  b.gasto_medio_semanal,
  t.gasto_medio_total_semanal,
  b.gasto_medio_semanal / t.gasto_medio_total_semanal AS participacao_orcamento
FROM base b
JOIN totais t
  ON b.ano = t.ano
 AND b.decil_renda = t.decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM vw_despesa_com_total
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ano</th><th>code</th><th>description</th><th>decil_renda</th><th>gasto_medio_semanal</th><th>gasto_medio_total_semanal</th><th>participacao_orcamento</th></tr></thead><tbody><tr><td>2024</td><td>1</td><td>Food & non-alcoholic drinks</td><td>1</td><td>38.1</td><td>1487.0000000000002</td><td>0.02562205783456624</td></tr><tr><td>2024</td><td>1.1</td><td>Food</td><td>1</td><td>35.2</td><td>1487.0000000000002</td><td>0.023671822461331538</td></tr><tr><td>2024</td><td>1.1.1</td><td>Bread, rice and cereals</td><td>1</td><td>3.3</td><td>1487.0000000000002</td><td>0.002219233355749831</td></tr><tr><td>2024</td><td>1.1.2</td><td>Pasta products</td><td>1</td><td>0.3</td><td>1487.0000000000002</td><td>2.0174848688634832E-4</td></tr><tr><td>2024</td><td>1.1.3</td><td>Buns, cakes, biscuits etc.</td><td>1</td><td>2.6</td><td>1487.0000000000002</td><td>0.0017484868863483522</td></tr><tr><td>2024</td><td>1.1.4</td><td>Pastry (savoury)</td><td>1</td><td>0.6</td><td>1487.0000000000002</td><td>4.0349697377269663E-4</td></tr><tr><td>2024</td><td>1.1.5</td><td>Beef (fresh, chilled or frozen)</td><td>1</td><td>0.8</td><td>1487.0000000000002</td><td>5.379959650302622E-4</td></tr><tr><td>2024</td><td>1.1.6</td><td>Pork (fresh, chilled or frozen)</td><td>1</td><td>0.3</td><td>1487.0000000000002</td><td>2.0174848688634832E-4</td></tr><tr><td>2024</td><td>1.1.7</td><td>Lamb (fresh, chilled or frozen)</td><td>1</td><td>0.3</td><td>1487.0000000000002</td><td>2.0174848688634832E-4</td></tr><tr><td>2024</td><td>1.1.8</td><td>Poultry (fresh, chilled or frozen)</td><td>1</td><td>1.0</td><td>1487.0000000000002</td><td>6.724949562878277E-4</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 6. Camada Gold – Esquema estrela (dimensões e tabela fato)
--
-- Nesta seção criamos as tabelas da camada Gold, seguindo o modelo em esquema estrela:
--
-- - Dimensões: `dim_renda`, `dim_categoria_consumo`, `dim_tempo`, `dim_geografia`;
-- - Tabela fato: `fato_despesa_familiar`, que consolida gasto médio semanal, gasto total e participação no orçamento.

-- %%
CREATE OR REPLACE TABLE dim_renda AS
SELECT
  ROW_NUMBER() OVER (ORDER BY decil_renda) AS id_renda,
  decil_renda,
  CONCAT(
    'Decil ',
    decil_renda,
    ' - ',
    CASE 
      WHEN decil_renda = 1  THEN '10% mais pobres'
      WHEN decil_renda = 10 THEN '10% mais ricos'
      ELSE 'faixa intermediária'
    END
  ) AS descricao_decil,
  'renda bruta por decil' AS tipo_renda
FROM (
  SELECT DISTINCT decil_renda
  FROM vw_despesa_long
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT * FROM dim_renda ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_renda</th><th>decil_renda</th><th>descricao_decil</th><th>tipo_renda</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>Decil 1 - 10% mais pobres</td><td>renda bruta por decil</td></tr><tr><td>2</td><td>2</td><td>Decil 2 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>3</td><td>3</td><td>Decil 3 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>4</td><td>4</td><td>Decil 4 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>5</td><td>5</td><td>Decil 5 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>6</td><td>6</td><td>Decil 6 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>7</td><td>7</td><td>Decil 7 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>8</td><td>8</td><td>Decil 8 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>9</td><td>9</td><td>Decil 9 - faixa intermediária</td><td>renda bruta por decil</td></tr><tr><td>10</td><td>10</td><td>Decil 10 - 10% mais ricos</td><td>renda bruta por decil</td></tr></tbody></table></div>

-- %%
CREATE OR REPLACE TABLE dim_categoria_consumo AS
SELECT
  ROW_NUMBER() OVER (ORDER BY code, description) AS id_categoria,
  code        AS codigo_categoria,
  description AS descricao_categoria,
  CASE 
    WHEN LOWER(description) LIKE '%pet%' THEN 1
    ELSE 0
  END AS flag_pet
FROM (
  SELECT DISTINCT code, description
  FROM vw_despesa_long
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM dim_categoria_consumo
ORDER BY flag_pet DESC, descricao_categoria
LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_categoria</th><th>codigo_categoria</th><th>descricao_categoria</th><th>flag_pet</th></tr></thead><tbody><tr><td>148</td><td>7.2.2</td><td>Petrol, diesel and other motor oils</td><td>1</td></tr><tr><td>171</td><td>9.3.5</td><td>Pets and pet food</td><td>1</td></tr><tr><td>187</td><td>gardens and pets</td><td>gardens and pets</td><td>1</td></tr><tr><td>184</td><td>Total expenditure </td><td>null</td><td>0</td></tr><tr><td>115</td><td>3.1.9</td><td>Accessories</td><td>0</td></tr><tr><td>59</td><td>11.2</td><td>Accommodation services</td><td>0</td></tr><tr><td>118</td><td>4.1</td><td>Actual rentals for housing</td><td>0</td></tr><tr><td>94</td><td>2</td><td>Alcoholic drink, tobacco & narcotics</td><td>0</td></tr><tr><td>95</td><td>2.1</td><td>Alcoholic drinks</td><td>0</td></tr><tr><td>55</td><td>11.1.2</td><td>Alcoholic drinks (away from home)</td><td>0</td></tr><tr><td>99</td><td>2.1.4</td><td>Alcopops (brought home)</td><td>0</td></tr><tr><td>8</td><td>1-12</td><td>All expenditure groups</td><td>0</td></tr><tr><td>163</td><td>9.1.1</td><td>Audio equipment and accessories, CD players</td><td>0</td></tr><tr><td>68</td><td>12.1.4</td><td>Baby toiletries and accessories (disposable)</td><td>0</td></tr><tr><td>42</td><td>1.1.9</td><td>Bacon and ham</td><td>0</td></tr><tr><td>78</td><td>12.5.2</td><td>Bank, building society, post office, credit card charges</td><td>0</td></tr><tr><td>38</td><td>1.1.5</td><td>Beef (fresh, chilled or frozen)</td><td>0</td></tr><tr><td>98</td><td>2.1.3</td><td>Beer, lager, ciders and perry (brought home)</td><td>0</td></tr><tr><td>177</td><td>9.5.1</td><td>Books</td><td>0</td></tr><tr><td>111</td><td>3.1.5</td><td>Boys' outer garments (5-15)</td><td>0</td></tr></tbody></table></div>

-- %%
CREATE OR REPLACE TABLE dim_tempo AS
SELECT
  1        AS id_tempo,
  2024     AS ano,
  'FYE 2024' AS periodo_label,
  DATE('2023-04-01') AS ano_inicio,
  DATE('2024-03-31') AS ano_fim;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
CREATE OR REPLACE TABLE dim_geografia AS
SELECT
  1               AS id_geografia,
  'UK total'      AS regiao,
  'Agregado Reino Unido' AS descricao_geografia;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
CREATE OR REPLACE TABLE fato_despesa_familiar AS
SELECT
  ROW_NUMBER() OVER (ORDER BY d.ano, d.decil_renda, c.id_categoria) AS id_fato,
  r.id_renda,
  c.id_categoria,
  t.id_tempo,
  g.id_geografia,
  d.gasto_medio_semanal,
  d.gasto_medio_total_semanal,
  d.participacao_orcamento
FROM vw_despesa_com_total d
JOIN dim_renda r
  ON d.decil_renda = r.decil_renda
JOIN dim_categoria_consumo c
  ON d.code = c.codigo_categoria
 AND d.description = c.descricao_categoria
JOIN dim_tempo t
  ON d.ano = t.ano
JOIN dim_geografia g
  ON g.id_geografia = 1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM fato_despesa_familiar
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_fato</th><th>id_renda</th><th>id_categoria</th><th>id_tempo</th><th>id_geografia</th><th>gasto_medio_semanal</th><th>gasto_medio_total_semanal</th><th>participacao_orcamento</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>7</td><td>1</td><td>1</td><td>38.1</td><td>1487.0000000000002</td><td>0.02562205783456624</td></tr><tr><td>2</td><td>1</td><td>8</td><td>1</td><td>1</td><td>255.1</td><td>1487.0000000000002</td><td>0.17155346334902485</td></tr><tr><td>3</td><td>1</td><td>9</td><td>1</td><td>1</td><td>35.2</td><td>1487.0000000000002</td><td>0.023671822461331538</td></tr><tr><td>4</td><td>1</td><td>10</td><td>1</td><td>1</td><td>3.3</td><td>1487.0000000000002</td><td>0.002219233355749831</td></tr><tr><td>5</td><td>1</td><td>11</td><td>1</td><td>1</td><td>5.1</td><td>1487.0000000000002</td><td>0.0034297242770679214</td></tr><tr><td>6</td><td>1</td><td>12</td><td>1</td><td>1</td><td>1.7</td><td>1487.0000000000002</td><td>0.001143241425689307</td></tr><tr><td>7</td><td>1</td><td>13</td><td>1</td><td>1</td><td>1.5</td><td>1487.0000000000002</td><td>0.0010087424344317416</td></tr><tr><td>8</td><td>1</td><td>14</td><td>1</td><td>1</td><td>1.2</td><td>1487.0000000000002</td><td>8.069939475453933E-4</td></tr><tr><td>9</td><td>1</td><td>15</td><td>1</td><td>1</td><td>0.7</td><td>1487.0000000000002</td><td>4.707464694014794E-4</td></tr><tr><td>10</td><td>1</td><td>16</td><td>1</td><td>1</td><td>1.4</td><td>1487.0000000000002</td><td>9.414929388029588E-4</td></tr></tbody></table></div>

-- %%
WITH fato_join AS (
  SELECT
    f.*,
    r.decil_renda,
    c.descricao_categoria,
    c.flag_pet
  FROM fato_despesa_familiar f
  JOIN dim_renda r        ON f.id_renda = r.id_renda
  JOIN dim_categoria_consumo c ON f.id_categoria = c.id_categoria
)
SELECT
  decil_renda,
  SUM(CASE WHEN flag_pet = 1 THEN participacao_orcamento ELSE 0 END) AS share_pets
FROM fato_join
GROUP BY decil_renda
ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>share_pets</th></tr></thead><tbody><tr><td>1</td><td>0.011230665770006724</td></tr><tr><td>2</td><td>0.012143253405658635</td></tr><tr><td>3</td><td>0.012924978926664797</td></tr><tr><td>4</td><td>0.013587730360847806</td></tr><tr><td>5</td><td>0.015350120731286651</td></tr><tr><td>6</td><td>0.013676615283699574</td></tr><tr><td>7</td><td>0.013131883648686813</td></tr><tr><td>8</td><td>0.013392519357360841</td></tr><tr><td>9</td><td>0.01347369320122993</td></tr><tr><td>10</td><td>0.011559439692574683</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 7. Análise – Qualidade dos dados
--
-- Antes da interpretação econômica, avaliamos a qualidade dos dados na tabela fato:
-- - presença de valores nulos;
-- - faixas mínimas e máximas de gasto e participação.

-- %%
SELECT
  SUM(CASE WHEN gasto_medio_semanal      IS NULL THEN 1 ELSE 0 END) AS n_nulos_gasto_medio,
  SUM(CASE WHEN gasto_medio_total_semanal IS NULL THEN 1 ELSE 0 END) AS n_nulos_gasto_total,
  SUM(CASE WHEN participacao_orcamento   IS NULL THEN 1 ELSE 0 END) AS n_nulos_share
FROM fato_despesa_familiar;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>n_nulos_gasto_medio</th><th>n_nulos_gasto_total</th><th>n_nulos_share</th></tr></thead><tbody><tr><td>197</td><td>0</td><td>197</td></tr></tbody></table></div>

-- %%
USE CATALOG workspace;
USE SCHEMA default;

CREATE OR REPLACE VIEW vw_fato_join AS
SELECT
  f.*,
  r.decil_renda,
  c.descricao_categoria,
  c.flag_pet
FROM fato_despesa_familiar f
JOIN dim_renda r
  ON f.id_renda = r.id_renda
JOIN dim_categoria_consumo c
  ON f.id_categoria = c.id_categoria;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT *
FROM vw_fato_join
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_fato</th><th>id_renda</th><th>id_categoria</th><th>id_tempo</th><th>id_geografia</th><th>gasto_medio_semanal</th><th>gasto_medio_total_semanal</th><th>participacao_orcamento</th><th>decil_renda</th><th>descricao_categoria</th><th>flag_pet</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>7</td><td>1</td><td>1</td><td>38.1</td><td>1487.0000000000002</td><td>0.02562205783456624</td><td>1</td><td>Food & non-alcoholic drinks</td><td>0</td></tr><tr><td>2</td><td>1</td><td>8</td><td>1</td><td>1</td><td>255.1</td><td>1487.0000000000002</td><td>0.17155346334902485</td><td>1</td><td>All expenditure groups</td><td>0</td></tr><tr><td>3</td><td>1</td><td>9</td><td>1</td><td>1</td><td>35.2</td><td>1487.0000000000002</td><td>0.023671822461331538</td><td>1</td><td>Food</td><td>0</td></tr><tr><td>4</td><td>1</td><td>10</td><td>1</td><td>1</td><td>3.3</td><td>1487.0000000000002</td><td>0.002219233355749831</td><td>1</td><td>Bread, rice and cereals</td><td>0</td></tr><tr><td>5</td><td>1</td><td>11</td><td>1</td><td>1</td><td>5.1</td><td>1487.0000000000002</td><td>0.0034297242770679214</td><td>1</td><td>Other meat and meat preparations</td><td>0</td></tr><tr><td>6</td><td>1</td><td>12</td><td>1</td><td>1</td><td>1.7</td><td>1487.0000000000002</td><td>0.001143241425689307</td><td>1</td><td>Fish and fish products</td><td>0</td></tr><tr><td>7</td><td>1</td><td>13</td><td>1</td><td>1</td><td>1.5</td><td>1487.0000000000002</td><td>0.0010087424344317416</td><td>1</td><td>Milk</td><td>0</td></tr><tr><td>8</td><td>1</td><td>14</td><td>1</td><td>1</td><td>1.2</td><td>1487.0000000000002</td><td>8.069939475453933E-4</td><td>1</td><td>Cheese and curd</td><td>0</td></tr><tr><td>9</td><td>1</td><td>15</td><td>1</td><td>1</td><td>0.7</td><td>1487.0000000000002</td><td>4.707464694014794E-4</td><td>1</td><td>Eggs</td><td>0</td></tr><tr><td>10</td><td>1</td><td>16</td><td>1</td><td>1</td><td>1.4</td><td>1487.0000000000002</td><td>9.414929388029588E-4</td><td>1</td><td>Other milk products</td><td>0</td></tr></tbody></table></div>

-- %%
SELECT
  decil_renda,
  descricao_categoria,
  gasto_medio_semanal,
  participacao_orcamento
FROM vw_fato_join
WHERE gasto_medio_semanal IS NULL
LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>descricao_categoria</th><th>gasto_medio_semanal</th><th>participacao_orcamento</th></tr></thead><tbody><tr><td>3</td><td>Dried vegetables</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Education</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Education fees</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Contract catering (food) and canteens</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Holiday abroad</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Room hire</td><td>null</td><td>null</td></tr><tr><td>6</td><td>Social protection</td><td>null</td><td>null</td></tr><tr><td>1</td><td>Other services and professional fees</td><td>null</td><td>null</td></tr><tr><td>5</td><td>Holiday spending</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Money, cash gifts given to children</td><td>null</td><td>null</td></tr><tr><td>1</td><td>National insurance contributions</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Pay off loan to clear other debt</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Windfall receipts from gambling etc¹¹</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Alcopops (brought home)</td><td>null</td><td>null</td></tr><tr><td>10</td><td>Dry cleaners, laundry and dyeing</td><td>null</td><td>null</td></tr><tr><td>1</td><td>Men's under garments</td><td>null</td><td>null</td></tr><tr><td>1</td><td>Boys' outer garments (5-15)</td><td>null</td><td>null</td></tr><tr><td>2</td><td>Infants' outer garments (under 5)</td><td>null</td><td>null</td></tr><tr><td>1</td><td>Children's under garments (under 16)</td><td>null</td><td>null</td></tr><tr><td>10</td><td>less housing benefit, rebates & allowances rec'd</td><td>null</td><td>null</td></tr></tbody></table></div>

-- %%
SELECT
  decil_renda,
  SUM(
    CASE 
      WHEN flag_pet = 1 THEN COALESCE(participacao_orcamento, 0)
      ELSE 0
    END
  ) AS share_pets
FROM vw_fato_join
GROUP BY decil_renda
ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>share_pets</th></tr></thead><tbody><tr><td>1</td><td>0.011230665770006724</td></tr><tr><td>2</td><td>0.012143253405658635</td></tr><tr><td>3</td><td>0.012924978926664797</td></tr><tr><td>4</td><td>0.013587730360847806</td></tr><tr><td>5</td><td>0.015350120731286651</td></tr><tr><td>6</td><td>0.013676615283699574</td></tr><tr><td>7</td><td>0.013131883648686813</td></tr><tr><td>8</td><td>0.013392519357360841</td></tr><tr><td>9</td><td>0.01347369320122993</td></tr><tr><td>10</td><td>0.011559439692574683</td></tr></tbody></table></div>

-- %%
CREATE OR REPLACE TABLE analise_share_pets AS
SELECT
  decil_renda,
  SUM(
    CASE 
      WHEN flag_pet = 1 THEN COALESCE(participacao_orcamento, 0)
      ELSE 0
    END
  ) AS share_pets
FROM vw_fato_join
GROUP BY decil_renda
ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

-- %%
CREATE OR REPLACE VIEW vw_fato_grupos AS
SELECT
  decil_renda,
  descricao_categoria,
  flag_pet,
  participacao_orcamento,
  CASE
    WHEN flag_pet = 1 THEN 'Pets'
    WHEN LOWER(descricao_categoria) LIKE '%food%' THEN 'Alimentação'
    ELSE 'Outras'
  END AS grupo_analise
FROM vw_fato_join;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
SELECT
  MIN(gasto_medio_semanal)    AS min_gasto,
  MAX(gasto_medio_semanal)    AS max_gasto,
  MIN(participacao_orcamento) AS min_share,
  MAX(participacao_orcamento) AS max_share
FROM fato_despesa_familiar;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>min_gasto</th><th>max_gasto</th><th>min_share</th><th>max_share</th></tr></thead><tbody><tr><td>0.1</td><td>961.6</td><td>2.1352921079603697E-5</td><td>0.17867458606240585</td></tr></tbody></table></div>

-- %%
SELECT
  id_renda,
  id_categoria,
  id_tempo,
  id_geografia,
  gasto_medio_semanal,
  gasto_medio_total_semanal,
  participacao_orcamento
FROM fato_despesa_familiar
LIMIT 20;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_renda</th><th>id_categoria</th><th>id_tempo</th><th>id_geografia</th><th>gasto_medio_semanal</th><th>gasto_medio_total_semanal</th><th>participacao_orcamento</th></tr></thead><tbody><tr><td>1</td><td>7</td><td>1</td><td>1</td><td>38.1</td><td>1487.0000000000002</td><td>0.02562205783456624</td></tr><tr><td>1</td><td>8</td><td>1</td><td>1</td><td>255.1</td><td>1487.0000000000002</td><td>0.17155346334902485</td></tr><tr><td>1</td><td>9</td><td>1</td><td>1</td><td>35.2</td><td>1487.0000000000002</td><td>0.023671822461331538</td></tr><tr><td>1</td><td>10</td><td>1</td><td>1</td><td>3.3</td><td>1487.0000000000002</td><td>0.002219233355749831</td></tr><tr><td>1</td><td>11</td><td>1</td><td>1</td><td>5.1</td><td>1487.0000000000002</td><td>0.0034297242770679214</td></tr><tr><td>1</td><td>12</td><td>1</td><td>1</td><td>1.7</td><td>1487.0000000000002</td><td>0.001143241425689307</td></tr><tr><td>1</td><td>13</td><td>1</td><td>1</td><td>1.5</td><td>1487.0000000000002</td><td>0.0010087424344317416</td></tr><tr><td>1</td><td>14</td><td>1</td><td>1</td><td>1.2</td><td>1487.0000000000002</td><td>8.069939475453933E-4</td></tr><tr><td>1</td><td>15</td><td>1</td><td>1</td><td>0.7</td><td>1487.0000000000002</td><td>4.707464694014794E-4</td></tr><tr><td>1</td><td>16</td><td>1</td><td>1</td><td>1.4</td><td>1487.0000000000002</td><td>9.414929388029588E-4</td></tr><tr><td>1</td><td>17</td><td>1</td><td>1</td><td>0.4</td><td>1487.0000000000002</td><td>2.689979825151311E-4</td></tr><tr><td>1</td><td>18</td><td>1</td><td>1</td><td>0.5</td><td>1487.0000000000002</td><td>3.3624747814391386E-4</td></tr><tr><td>1</td><td>19</td><td>1</td><td>1</td><td>0.2</td><td>1487.0000000000002</td><td>1.3449899125756554E-4</td></tr><tr><td>1</td><td>20</td><td>1</td><td>1</td><td>2.2</td><td>1487.0000000000002</td><td>0.001479488903833221</td></tr><tr><td>1</td><td>21</td><td>1</td><td>1</td><td>0.3</td><td>1487.0000000000002</td><td>2.0174848688634832E-4</td></tr><tr><td>1</td><td>22</td><td>1</td><td>1</td><td>0.3</td><td>1487.0000000000002</td><td>2.0174848688634832E-4</td></tr><tr><td>1</td><td>23</td><td>1</td><td>1</td><td>0.6</td><td>1487.0000000000002</td><td>4.0349697377269663E-4</td></tr><tr><td>1</td><td>24</td><td>1</td><td>1</td><td>0.1</td><td>1487.0000000000002</td><td>6.724949562878277E-5</td></tr><tr><td>1</td><td>25</td><td>1</td><td>1</td><td>2.1</td><td>1487.0000000000002</td><td>0.0014122394082044384</td></tr><tr><td>1</td><td>26</td><td>1</td><td>1</td><td>0.1</td><td>1487.0000000000002</td><td>6.724949562878277E-5</td></tr></tbody></table></div>

-- %%
SELECT
  decil_renda,
  SUM(
    CASE 
      WHEN flag_pet = 1 THEN COALESCE(participacao_orcamento, 0)
      ELSE 0
    END
  ) AS share_pets
FROM vw_fato_join
GROUP BY decil_renda
ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>share_pets</th></tr></thead><tbody><tr><td>1</td><td>0.011230665770006724</td></tr><tr><td>2</td><td>0.012143253405658635</td></tr><tr><td>3</td><td>0.012924978926664797</td></tr><tr><td>4</td><td>0.013587730360847806</td></tr><tr><td>5</td><td>0.015350120731286651</td></tr><tr><td>6</td><td>0.013676615283699574</td></tr><tr><td>7</td><td>0.013131883648686813</td></tr><tr><td>8</td><td>0.013392519357360841</td></tr><tr><td>9</td><td>0.01347369320122993</td></tr><tr><td>10</td><td>0.011559439692574683</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 8. Análise – Participação dos gastos com pets por decil de renda
--
-- Aqui calculamos a participação total dos gastos com pets no orçamento de cada decil de renda e geramos a curva usada como “curva de Engel aproximada” para pets.

-- %%
SELECT
  decil_renda,
  100 * share_pets AS share_pets_pct
FROM (
    SELECT
      decil_renda,
      SUM(
        CASE
          WHEN flag_pet = 1 THEN COALESCE(participacao_orcamento, 0)
          ELSE 0
        END
      ) AS share_pets
    FROM vw_fato_join
    GROUP BY decil_renda
) t
ORDER BY decil_renda;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>share_pets_pct</th></tr></thead><tbody><tr><td>1</td><td>1.1230665770006725</td></tr><tr><td>2</td><td>1.2143253405658634</td></tr><tr><td>3</td><td>1.2924978926664796</td></tr><tr><td>4</td><td>1.3587730360847805</td></tr><tr><td>5</td><td>1.5350120731286652</td></tr><tr><td>6</td><td>1.3676615283699574</td></tr><tr><td>7</td><td>1.3131883648686813</td></tr><tr><td>8</td><td>1.3392519357360841</td></tr><tr><td>9</td><td>1.347369320122993</td></tr><tr><td>10</td><td>1.1559439692574682</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## 9. Análise – Comparação Pets x Alimentação (Lei de Engel)
--
-- Nesta etapa comparamos a participação dos gastos com pets e alimentação no orçamento, por decil de renda, para observar o comportamento esperado pela Lei de Engel.

-- %%
SELECT
  decil_renda,
  grupo_analise,
  SUM(COALESCE(participacao_orcamento, 0)) AS share
FROM vw_fato_grupos
GROUP BY decil_renda, grupo_analise
ORDER BY decil_renda, grupo_analise;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>decil_renda</th><th>grupo_analise</th><th>share</th></tr></thead><tbody><tr><td>1</td><td>Alimentação</td><td>0.05117686617350369</td></tr><tr><td>1</td><td>Outras</td><td>0.7401479488903834</td></tr><tr><td>1</td><td>Pets</td><td>0.011230665770006724</td></tr><tr><td>2</td><td>Alimentação</td><td>0.058867040621340086</td></tr><tr><td>2</td><td>Outras</td><td>0.7261912100104795</td></tr><tr><td>2</td><td>Pets</td><td>0.012143253405658635</td></tr><tr><td>3</td><td>Alimentação</td><td>0.05371358995972653</td></tr><tr><td>3</td><td>Outras</td><td>0.7279198276669477</td></tr><tr><td>3</td><td>Pets</td><td>0.012924978926664797</td></tr><tr><td>4</td><td>Alimentação</td><td>0.05101501159432081</td></tr><tr><td>4</td><td>Outras</td><td>0.728367438265327</td></tr><tr><td>4</td><td>Pets</td><td>0.013587730360847806</td></tr><tr><td>5</td><td>Alimentação</td><td>0.047775094860296664</td></tr><tr><td>5</td><td>Outras</td><td>0.7317695757157641</td></tr><tr><td>5</td><td>Pets</td><td>0.015350120731286651</td></tr><tr><td>6</td><td>Alimentação</td><td>0.04735979009511316</td></tr><tr><td>6</td><td>Outras</td><td>0.7326336503771724</td></tr><tr><td>6</td><td>Pets</td><td>0.013676615283699574</td></tr><tr><td>7</td><td>Alimentação</td><td>0.04428127647557189</td></tr><tr><td>7</td><td>Outras</td><td>0.7382942671561711</td></tr><tr><td>7</td><td>Pets</td><td>0.013131883648686813</td></tr><tr><td>8</td><td>Alimentação</td><td>0.04570102650760423</td></tr><tr><td>8</td><td>Outras</td><td>0.7403213195793096</td></tr><tr><td>8</td><td>Pets</td><td>0.013392519357360841</td></tr><tr><td>9</td><td>Alimentação</td><td>0.04091219678852069</td></tr><tr><td>9</td><td>Outras</td><td>0.7503202938161936</td></tr><tr><td>9</td><td>Pets</td><td>0.01347369320122993</td></tr><tr><td>10</td><td>Alimentação</td><td>0.0325244824594025</td></tr><tr><td>10</td><td>Outras</td><td>0.7668743027147643</td></tr><tr><td>10</td><td>Pets</td><td>0.011559439692574683</td></tr></tbody></table></div>
